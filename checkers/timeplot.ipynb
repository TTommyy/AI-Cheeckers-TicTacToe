# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = "timing_results.csv"
orderd_data = pd.read_csv(csv_file, header=None, names=['Depth', 'Time'])
orderd_data
# Out:
#     Depth        Time
# 0       1    0.000659
# 1       2    0.001240
# 2       3    0.004250
# 3       4    0.007357
# 4       5    0.020921
# 5       6    0.021825
# 6       7    0.042200
# 7       8    0.095118
# 8       9    0.286659
# 9      10    0.599030
# 10     11    1.963540
# 11     12    4.519850
# 12     13   11.488400
# 13     14   28.352500
# 14     15   72.117700
# 15     16  192.558000

# %%
csv_file = "random_timing_results.csv"
random_data = pd.read_csv(csv_file, header=None, names=['Depth', 'Time'])
random_data
# Out:
#     Depth        Time
# 0       1    0.000768
# 1       2    0.001426
# 2       3    0.004865
# 3       4    0.009344
# 4       5    0.022532
# 5       6    0.024525
# 6       7    0.082539
# 7       8    0.108010
# 8       9    0.387815
# 9      10    0.715172
# 10     11    1.553260
# 11     12    3.851260
# 12     13   11.771400
# 13     14   25.130400
# 14     15   55.379600
# 15     16  158.857000

# %%
csv_file = "reverse_timing_results.csv"
reverse_data = pd.read_csv(csv_file, header=None, names=['Depth', 'Time'])
reverse_data
# Out:
#     Depth        Time
# 0       1    0.000615
# 1       2    0.001251
# 2       3    0.004509
# 3       4    0.009435
# 4       5    0.019943
# 5       6    0.029260
# 6       7    0.072268
# 7       8    0.154681
# 8       9    0.502472
# 9      10    1.190400
# 10     11    3.347290
# 11     12    7.737330
# 12     13   22.738600
# 13     14   49.222000
# 14     15  156.357000
# 15     16  335.469000

# %%
csv_file = "min_max_timing_results.csv"
min_max_data = pd.read_csv(csv_file, header=None, names=['Depth', 'Time'])
min_max_data
# Out:
#    Depth        Time
# 0      1    0.000515
# 1      2    0.003113
# 2      3    0.014000
# 3      4    0.041315
# 4      5    0.137254
# 5      6    0.672683
# 6      7    3.402400
# 7      8   16.290100
# 8      9   81.271900
# 9     10  390.654000

# %%
plt.figure(figsize=(6, 4))
plt.plot(orderd_data['Depth'], orderd_data['Time'], marker='o', label="orderd_data")
plt.plot(random_data['Depth'], random_data['Time'], marker='o', label="random_data")
plt.plot(reverse_data['Depth'], reverse_data['Time'], marker='o', label="reverse_data")
plt.plot(min_max_data['Depth'], min_max_data['Time'], marker='o', label="min_max_data")


plt.title('Alpha-Beta Search Performance')
plt.xlabel('Depth')
plt.ylabel('Time (seconds)')
plt.legend();
plt.grid(True)


plt.show()
